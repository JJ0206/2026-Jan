# %% [markdown]
# <a href="https://colab.research.google.com/github/JJ0206/2026-Jan/blob/main/%EC%B2%AD%EC%86%8C%EB%85%84IT%EA%B2%BD%EC%8B%9C%EB%8C%80%ED%9A%8C_%EB%8C%80%EB%B9%84_dajikstra_%EB%8B%A4%EC%9D%B5%EC%8A%A4%ED%8A%B8%EB%9D%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %%
import heapq
import sys

# 무한을 의미하는 값으로 설정
INF = float('inf')

def dijkstra(start, graph, distance):
    q = []
    # 시작 노드로 가기 위한 최단 경로는 0으로 설정하여 큐에 삽입
    heapq.heappush(q, (0, start))
    distance[start] = 0

    while q:
        # 가장 최단 거리가 짧은 노드에 대한 정보 꺼내기
        dist, now = heapq.heappop(q)

        # 현재 노드가 이미 처리된 적이 있는 노드라면 무시
        if distance[now] < dist:
            continue

        # 현재 노드와 연결된 다른 인접한 노드들을 확인
        for i in graph[now]:
            cost = dist + i[1]
            # 현재 노드를 거쳐서, 다른 노드로 이동하는 거리가 더 짧은 경우
            if cost < distance[i[0]]:
                distance[i[0]] = cost
                heapq.heappush(q, (cost, i[0]))

# 데이터 입력 예시
n, m = 6, 11 # 노드 개수, 간선 개수
start = 1    # 시작 노드 번호

# 각 노드에 연결되어 있는 노드에 대한 정보를 담는 리스트
graph = [[] for i in range(n + 1)]
# 최단 거리 테이블을 모두 무한으로 초기화
distance = [INF] * (n + 1)

# 모든 간선 정보 입력 (출발, 도착, 비용)
edges = [
    (1, 2, 2), (1, 3, 5), (1, 4, 1),
    (2, 3, 3), (2, 4, 2),
    (3, 2, 3), (3, 6, 5),
    (4, 3, 3), (4, 5, 1),
    (5, 3, 1), (5, 6, 2)
]

for u, v, w in edges:
    graph[u].append((v, w))

# 다익스트라 알고리즘 실행
dijkstra(start, graph, distance)

# 모든 노드로 가기 위한 최단 거리 출력
for i in range(1, n + 1):
    if distance[i] == INF:
        print("도착 불가")
    else:
        print(f"{start}번 노드에서 {i}번 노드까지 거리: {distance[i]}")
# Out:
# 1번 노드에서 1번 노드까지 거리: 0
# 1번 노드에서 2번 노드까지 거리: 2
# 1번 노드에서 3번 노드까지 거리: 3
# 1번 노드에서 4번 노드까지 거리: 1
# 1번 노드에서 5번 노드까지 거리: 2
# 1번 노드에서 6번 노드까지 거리: 4
